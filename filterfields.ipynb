# %%
import pandas as pd

# %%
pwd
# Out:
# '/Users/saichaitanyadasari/Desktop/Hotel-clustering'

# %%
# md=pd.read_csv("madrid_listings_filtered.csv")
# be=pd.read_csv("berlin_listings_filtered.csv")
bo=pd.read_csv("datasets/listings.csv")
# me=pd.read_csv("melbourn_listings_filtered.csv")
# p=pd.read_csv("paris_listings_filtered.csv")
# ed=pd.read_csv("edinburgh_listings_filtered.csv")
# am=pd.read_csv("amsterdam_listings_filtered.csv")

# %%
bo.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'summary',
#        'space', 'description', 'experiences_offered', 'neighborhood_overview',
#        'notes', 'transit', 'access', 'interaction', 'house_rules',
#        'thumbnail_url', 'medium_url', 'picture_url', 'xl_picture_url',
#        'host_id', 'host_url', 'host_name', 'host_since', 'host_location',
#        'host_about', 'host_response_time', 'host_response_rate',
#        'host_acceptance_rate', 'host_is_superhost', 'host_thumbnail_url',
#        'host_picture_url', 'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'street',
#        'neighbourhood', 'neighbourhood_cleansed',
#        'neighbourhood_group_cleansed', 'city', 'state', 'zipcode', 'market',
#        'smart_location', 'country_code', 'country', 'latitude', 'longitude',
# ...

# %%
len(bo.columns)
# Out:
# 95

# %%
len(be.columns)
# Out:
# 44

# %%
len(bo.columns)
# Out:
# 44

# %%
len(me.columns)
# Out:
# 44

# %%
len(p.columns)
# Out:
# 44

# %%
len(ed.columns)
# Out:
# 44

# %%
len(am.columns)
# Out:
# 44

# %%
md.describe()
# Out:
#                  id  host_acceptance_rate      latitude     longitude  \
# count  2.083700e+04                   0.0  20837.000000  20837.000000
# mean   2.356026e+07                   NaN     40.420548     -3.694500
# std    1.083667e+07                   NaN      0.021881      0.027793
# min    6.369000e+03                   NaN     40.319480     -3.890940
# 25%    1.608985e+07                   NaN     40.409550     -3.707490
# 50%    2.459474e+07                   NaN     40.418900     -3.701180
# 75%    3.401318e+07                   NaN     40.429020     -3.689110
# max    3.873002e+07                   NaN     40.573990     -3.527660
#
#        accommodates     bathrooms      bedrooms          beds  \
# count  20837.000000  20827.000000  20828.000000  20786.000000
# mean       3.283246      1.302876      1.438880      1.981718
# std        2.010439      0.762046      2.221507      1.665901
# min        1.000000      0.000000      0.000000      0.000000
# ...

# %%
be.describe()
# Out:
#           bathrooms      bedrooms          beds  review_scores_rating  \
# count  22520.000000  22534.000000  22512.000000          18160.000000
# mean       1.092673      1.162377      1.632818             94.414042
# std        0.329884      0.670457      1.582169              7.640080
# min        0.000000      0.000000      0.000000             20.000000
# 25%        1.000000      1.000000      1.000000             92.000000
# 50%        1.000000      1.000000      1.000000             97.000000
# 75%        1.000000      1.000000      2.000000            100.000000
# max        8.500000     28.000000     98.000000            100.000000
#
#        review_scores_accuracy  review_scores_cleanliness  \
# count            18135.000000               18138.000000
# mean                 9.664020                   9.325008
# std                  0.739989                   1.032020
# min                  2.000000                   2.000000
# ...

# %%
bo.describe()
# Out:
#                  id  host_acceptance_rate      latitude     longitude  \
# count  2.003000e+04                   0.0  20030.000000  20030.000000
# mean   1.541725e+07                   NaN     52.365212      4.888977
# std    8.569404e+06                   NaN      0.015996      0.035573
# min    2.818000e+03                   NaN     52.288378      4.753247
# 25%    8.188423e+06                   NaN     52.355126      4.863595
# 50%    1.563049e+07                   NaN     52.364590      4.886387
# 75%    2.202577e+07                   NaN     52.375074      4.908288
# max    3.058041e+07                   NaN     52.424713      5.027689
#
#        accommodates     bathrooms     bedrooms          beds  guests_included  \
# 50%    1.563049e+07                   NaN     52.364590      4.886387
# 75%    2.202577e+07                   NaN     52.375074      4.908288
# max    3.058041e+07                   NaN     52.424713      5.027689
#
#        accommodates     bathrooms     bedrooms          beds  guests_included  \
# count  20030.000000  20020.000000  20022.00000  20023.000000     20030.000000
# mean       2.891912      1.137662      1.44506      1.849223         1.468997
# std        1.318760      0.793903      0.88568      1.389664         0.937890
# ...

# %%
new_f  = pd.concat([md,be,bo,me,p,ed,am], ignore_index=True)

# %%
new_f
# Out:
#               id                                               name  \
# 0           6369  Rooftop terrace room with ensuite bathroom, Airc.
# 1          21853                               Bright and airy room
# 2          24805                             Gran Via Studio Madrid
# 3          24836                     Select the Madrid more "cool".
# 4          26825                 Single Room whith private Bathroom
# ...          ...                                                ...
# 177413  30576148   Family House City + free Parking+garden (160 m2)
# 177414  30577727                  Home Sweet Home in Indische Buurt
# 177415  30578037             Amsterdam Cozy apartment nearby center
# 177416  30579673            Home Sweet Home for a Guest or a Couple
# 177417  30580413        Cosy two bedroom appartment near 'de Pijp'!
#
#                                                   summary  \
# 0       Atico en la calle Principe de Vergara, con bañ...
# ...

# %%
new_f.describe()
# Out:
#            bathrooms       bedrooms           beds  review_scores_rating  \
# count  177252.000000  177288.000000  177012.000000         142045.000000
# mean        1.167564       1.297454       1.807747             93.593059
# std         0.678868       1.345864       1.468311              8.043359
# min         0.000000       0.000000       0.000000             20.000000
# 25%         1.000000       1.000000       1.000000             91.000000
# 50%         1.000000       1.000000       1.000000             96.000000
# 75%         1.000000       2.000000       2.000000             99.000000
# max       100.500000      50.000000     100.000000            100.000000
#
#        review_scores_accuracy  review_scores_cleanliness  \
# count           141928.000000              141961.000000
# mean                 9.611500                   9.350603
# std                  0.789424                   0.984852
# min                  2.000000                   2.000000
# ...

# %%
new_f.to_csv('combined_filtered_locations.csv', index=False)

# %%
pds_f = bo[keep_col]

# %%
keep_col = ['id','name','summary','space',
    'transit', 'access', 'interaction', 'house_rules',
      
        'host_location',
       'host_about', 'host_response_time', 'host_response_rate',
       'host_acceptance_rate', 'host_is_superhost',
       'host_neighbourhood',
       'host_identity_verified',  'city', 'country', 'latitude', 'longitude',
       'is_location_exact', 'property_type', 'room_type', 'accommodates',
       'bathrooms', 'bedrooms', 'beds', 'bed_type', 'amenities', 
       'price', 'monthly_price', 'security_deposit',
       'cleaning_fee', 'guests_included',  'minimum_nights',
      'review_scores_rating',
       'review_scores_accuracy', 'review_scores_cleanliness',
       'review_scores_checkin', 'review_scores_communication',
       'review_scores_location', 'review_scores_value', 'requires_license',
    
      'cancellation_policy']

# %%
# for the user data

# %%
pds_f
# Out:
#             id                                           name  \
# 0     12147973                     Sunny Bungalow in the City
# 1      3075044              Charming room in pet friendly apt
# 2         6976               Mexican Folk Art Haven in Boston
# 3      1436513  Spacious Sunny Bedroom Suite in Historic Home
# 4      7651065                            Come Home to Boston
# ...        ...                                            ...
# 3580   8373729                           Big cozy room near T
# 3581  14844274            BU Apartment DexterPark Bright room
# 3582  14585486                       Gorgeous funky apartment
# 3583  14603878          Great Location; Train and Restaurants
# 3584  14504422             (K1) Private Room near Harvard/MIT
#
#                                                 summary  \
# 0     Cozy, sunny, family home.  Master bedroom high...
# 1     Charming and quiet room in a second floor 1910...
# ...

# %%
pwd
# Out:
# '/Users/saichaitanyadasari/Documents/GitHub/Hotel-clustering'

# %%
ds = pd.read_csv('../reviews_summary.csv')

# %%
ds
# Out:
#         listing_id         id        date  reviewer_id reviewer_name  \
# 0             2015   69544350  2016-04-11      7178145         Rahel
# 1             2015   69990732  2016-04-15     41944715        Hannah
# 2             2015   71605267  2016-04-26     30048708        Victor
# 3             2015   73819566  2016-05-10     63697857          Judy
# 4             2015   74293504  2016-05-14     10414887        Romina
# ...            ...        ...         ...          ...           ...
# 401958    29784461  345904235  2018-11-06    160580302      Michelle
# 401959    29792124  345428291  2018-11-05    117705698         Kevin
# 401960    29817383  346045092  2018-11-07     20344466         Johan
# 401961    29849565  346027793  2018-11-07    114291292      Matthias
# 401962    29849565  346048710  2018-11-07     10938217       Mélanie
#
#                                                  comments
# 0       Mein Freund und ich hatten gute gemütliche vie...
# ...

# %%
keep_cool = ['id','reviewer_id','reviewer_name']

# %%
users_f = f[keep_cool]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-67f18f0d631d> in <module>
# ----> 1 users_f = f[keep_cool]
#
# NameError: name 'f' is not defined

# %%
ds.drop(["listing_id", "date","id","comments"], axis = 1, inplace = True)

# %%
ds
# Out:
#         reviewer_id reviewer_name
# 0           7178145         Rahel
# 1          41944715        Hannah
# 2          30048708        Victor
# 3          63697857          Judy
# 4          10414887        Romina
# ...             ...           ...
# 401958    160580302      Michelle
# 401959    117705698         Kevin
# 401960     20344466         Johan
# 401961    114291292      Matthias
# 401962     10938217       Mélanie
#
# [401963 rows x 2 columns]

# %%
ds.drop(ds.tail(1963).index,inplace=True)

# %%
ds
# Out:
#         reviewer_id reviewer_name
# 0           7178145         Rahel
# 1          41944715        Hannah
# 2          30048708        Victor
# 3          63697857          Judy
# 4          10414887        Romina
# ...             ...           ...
# 399995    152995511      Jonathan
# 399996    213592267         Jenna
# 399997     84177158        Buddhi
# 399998    142663298         Fahad
# 399999    151053489        Julius
#
# [400000 rows x 2 columns]

# %%
ds.drop(ds.tail(45000).index,inplace=True)

# %%
ds
# Out:
#       reviewer_id reviewer_name
# 0         7178145         Rahel
# 1        41944715        Hannah
# 2        30048708        Victor
# 3        63697857          Judy
# 4        10414887        Romina
# ...           ...           ...
# 4995     80929862         Karin
# 4996     10589594        Stefan
# 4997     26241292        Miriam
# 4998     39899618    Frederikke
# 4999    105809089         Mirta
#
# [5000 rows x 2 columns]

# %%
pds_f.to_csv('filtered_BOSTON_Listings.csv', index=False)
