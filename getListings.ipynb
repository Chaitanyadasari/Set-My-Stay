# %%
import pandas as pd

# %%
pwd
# Out:
# '/Users/saichaitanyadasari/Documents/GitHub/Hotel-clustering'

# %%
df1 = pd.read_csv('datasets/translated_amsterdam.csv')

# %%
df1
# Out:
#     Unnamed: 0      id                                               name  \
# 0            1    3209                  Quiet apt near center, great view
# 1            2   20168         100%Centre-Studio 1 Private Floor/Bathroom
# 2            4   27886  Romantic, stylish B&B houseboat in canal district
# 3            5   28658                Cosy guest room near city centre -1
# 4           10   42970        Comfortable room@PERFECT location + 2 bikes
# ..         ...     ...                                                ...
# 95         193  359298                   Sunny Roof Top in Beautiful Area
# 96         194  359408                    Comfortable apt. in city center
# 97         195  361342                ★ Stunning City Centre Apartment #3
# 98         196  362458   Bright, newly renovated apartment in Center-East
# 99         197  364728     Fancy decorated little Tsarina  privéapartment
#
#                                               summary  \
# ...

# %%
df1.id.unique()
# Out:
# array([  3209,  20168,  27886,  28658,  42970,  43980,  44391,  46386,
#         50515,  50570,  53067,  53671,  53692,  55256,  55703,  55868,
#         57408,  57978,  62015,  64769,  65230,  68290,  68873,  69042,
#         75382,  82482,  84057,  91535,  96048,  97476, 107972, 115795,
#        118097, 118117, 120872, 137026, 147270, 150634, 156815, 162467,
#        169356, 170223, 171631, 184282, 188347, 189754, 190585, 193038,
#        198307, 199844, 200461, 203658, 204014, 213721, 217692, 221943,
#        222516, 226121, 230710, 236632, 237017, 239647, 245927, 247805,
#        251444, 252725, 253650, 254104, 255177, 260187, 261902, 262209,
#        262394, 271787, 272597, 274688, 278823, 283621, 286500, 289071,
#        290701, 291637, 293337, 297220, 300067, 302426, 305809, 307470,
#        311124, 313778, 329577, 335197, 340994, 345397, 350271, 359298,
#        359408, 361342, 362458, 364728])

# %%
df2 = pd.read_csv('datasets/translated_berlin.csv')

# %%
df2
# Out:
#     Unnamed: 0      id                                              name  \
# 0            0    2015  Berlin-Mitte Value! Quiet courtyard/very central
# 1            2    3176                   Fabulous Flat in great Location
# 2            3    3309                 BerlinSpot Schöneberg near KaDeWe
# 3            4    7071                  BrightRoom with sunny greenview!
# 4            8   16644                In the Heart of Berlin - Kreuzberg
# ..         ...     ...                                               ...
# 95         258  253005                    Pension am Traveplatz Zimmer 3
# 96         269  257373                Sunny boutique studio Prenzl. Berg
# 97         271  257766                100 qm Penthouse-Loft Berlin-Mitte
# 98         276  261452               Wendt apartment, 1st floor, central
# 99         294  267399                 Attention to Every Little Detail.
#
#                                               summary  \
# ...

# %%
df2.id.unique()
# Out:
# array([  2015,   3176,   3309,   7071,  16644,  17409,  20858,  21869,
#         22415,  22677,  23834,  26543,  28268,  30295,  36480,  37052,
#         38074,  42809,  44423,  46172,  52734,  54952,  60161,  68142,
#         68448,  72079,  81049,  83183,  83614,  87549, 102882, 106331,
#        107968, 109658, 117649, 135097, 145249, 147946, 151249, 153015,
#        155048, 157839, 159454, 160517, 163287, 163411, 168615, 169603,
#        169907, 170582, 170974, 171746, 174579, 176342, 176355, 178347,
#        179102, 180440, 183918, 183996, 186851, 186999, 187206, 187326,
#        188922, 194374, 194465, 196149, 201224, 204609, 205296, 214491,
#        214518, 220445, 220808, 221015, 226925, 227072, 229348, 229363,
#        230824, 236552, 238569, 239139, 239314, 240169, 240735, 242366,
#        242794, 243057, 248192, 249220, 249419, 251548, 252967, 253005,
#        257373, 257766, 261452, 267399])

# %%
df3 = pd.read_csv('datasets/translated_boston.csv')

# %%
df3
# Out:
#     Unnamed: 0       id                                               name  \
# 0            1  3075044                  Charming room in pet friendly apt
# 1            2     6976                   Mexican Folk Art Haven in Boston
# 2            3  1436513      Spacious Sunny Bedroom Suite in Historic Home
# 3            4  7651065                                Come Home to Boston
# 4            6  5706985                New Lrg Studio apt 15 min to Boston
# ..         ...      ...                                                ...
# 95         181  8354938  2 bedroom Jamaica Plain Egleston Square w/ par...
# 96         182  5025015                     Beautiful Apartment in Boston!
# 97         185  9349646                       Family-friendly private room
# 98         187  5124772                Beautiful Victorian on Quiet Street
# 99         188  3977877                  Full One-Bedroom in Jamaica Plain
#
#                                               summary  \
# ...

# %%
df3.id.unique()
# Out:
# array([ 3075044,     6976,  1436513,  7651065,  5706985,  2843445,
#          849408,  1668313,   225979,  3420384,  2583074, 13251243,
#          225834,  1810172,  6513924,  1861070,  4283698,  8548176,
#         4922204,  4085362,  3755609,  1936861,  4461111,  1724900,
#         1494726,  3575220,  1591827,  3229255,  1721016, 12927298,
#          735970,  6730758, 14246616,  5601743,   519272,  8481291,
#         6990904,   197727,   932853,  7956634,   568234,  1030500,
#        12930651,  4223387, 12855396,  2963419,  5904732,  3591359,
#         4975581,  6364042, 13215952,  1301500,  8923817, 13041602,
#         3342094,  5652147,  2875267,  9485607,  7273770,  5405928,
#         1113272, 12647606,  7879708,  3881993,  6602217,  2308630,
#         4098410,  6322283,  7823025,  9549850, 11826815,  4765070,
#        10253591,  1881298,   210097,  6059968,  6862758,   799701,
#          750438,  9712731,  3371091,  6106955,  2698996,  4025194,
# ...

# %%
df4 = pd.read_csv('datasets/translated_edinburgh.csv')

# %%
df4
# Out:
#     Unnamed: 0      id                                               name  \
# 0            0   15420                  Georgian Boutique Apt City Centre
# 1            1   24288  Cool central Loft, sleeps 4, 2 double bed+en-s...
# 2            2   38628                              Edinburgh Holiday Let
# 3            3   44552                  Double room - spacious Leith flat
# 4            5   48645                     Large Sunny Room on Royal Mile
# ..         ...     ...                                                ...
# 95         176  640398                Spacious Twin Room in v. good area.
# 96         177  641377                     Twin Room in Comfy Family Home
# 97         178  641458                           Ocean's Family Apartment
# 98         179  641460  2 Bedroom Apartment (5 persons) with FREE Parking
# 99         180  641461  2 Bedroom Apartment (4 persons) with FREE parking
#
#                                               summary  \
# ...

# %%
df4.id.unique()
# Out:
# array([ 15420,  24288,  38628,  44552,  48645,  54188,  58682,  74877,
#         85620,  87097,  93904, 112625, 118314, 122930, 145675, 159769,
#        163870, 170756, 170762, 177944, 180429, 185514, 186691, 229494,
#        241054, 241511, 243941, 256783, 291287, 310380, 317080, 327159,
#        327161, 340452, 355938, 356028, 361050, 368502, 388297, 389318,
#        391558, 391610, 391611, 399593, 405790, 408831, 428822, 447206,
#        448055, 449075, 481841, 485856, 493689, 497140, 500696, 509191,
#        513895, 520802, 521385, 522004, 523134, 523395, 530628, 545821,
#        551401, 551652, 562350, 569604, 573745, 579038, 591360, 592226,
#        603443, 603446, 603493, 603497, 603498, 603501, 603502, 603671,
#        603672, 603674, 603726, 603996, 605856, 607248, 611124, 612137,
#        615726, 615913, 622225, 622930, 627527, 633029, 639079, 640398,
#        641377, 641458, 641460, 641461])

# %%
df5 = pd.read_csv('datasets/translated_madrid.csv')

# %%
df5
# Out:
#     Unnamed: 0      id                                            name  \
# 0            1   21853                            Bright and airy room
# 1            2   24805                          Gran Via Studio Madrid
# 2            3   24836                  Select the Madrid more "cool".
# 3            8   59923  Habitación para féminas en el centro de Madrid
# 4            9   62423    MAGIC ARTISTIC HOUSE IN THE CENTER OF MADRID
# ..         ...     ...                                             ...
# 95         222  548995                CHIC and CENTRAL apartment +WIFI
# 96         226  552183             Nice apartment. historic center Mad
# 97         229  558690             Bº Salamanca -5pax -3bedrooms - 2wc
# 98         233  568190             Rooms to rent to students,tourists
# 99         237  578731               CENTRIC, QUIET, BRIGHT APARTMENT.
#
#                                               summary  \
# 0   We have a quiet and sunny room with a good vie...
# ...

# %%
df5.id.unique()
# Out:
# array([ 21853,  24805,  24836,  59923,  62423,  70059,  70310,  70315,
#         70316,  72150,  84719,  86042,  89954,  93100, 101507, 102040,
#        102091, 112650, 120293, 123864, 136058, 150123, 153798, 171144,
#        191661, 196197, 199016, 199201, 209780, 214000, 219303, 229664,
#        260951, 261878, 261959, 263748, 264054, 281224, 282715, 283862,
#        289555, 310333, 310678, 315682, 318826, 322548, 334281, 336869,
#        337292, 339144, 339751, 341939, 342557, 345233, 345249, 347510,
#        353713, 353746, 361053, 370815, 400139, 406341, 406697, 410699,
#        429942, 431806, 434874, 439699, 442986, 449218, 462072, 467552,
#        470132, 477656, 479718, 483048, 488462, 493238, 497706, 502918,
#        506956, 507614, 514917, 515008, 515339, 518208, 521162, 522563,
#        524003, 526513, 531677, 531854, 540937, 544736, 548212, 548995,
#        552183, 558690, 568190, 578731])

# %%
df6 = pd.read_csv('datasets/translated_paris.csv')

# %%
df6
# Out:
#     Unnamed: 0      id                                               name  \
# 0            2    5396                     Explore the heart of old Paris
# 1            4    7964                  Large & sunny flat with balcony !
# 2            6    9359    Cozy, Central Paris: WALK or VELIB EVERYWHERE !
# 3            8   10010                   Paris view from my balcony - B&B
# 4            9   10270                Be charmed by real Paris 11th - B&B
# ..         ...     ...                                                ...
# 95         230  130420                 Charming Apartment 2BR in Paris 9e
# 96         231  131487       Mondrian Design 1BR Apt Near Arc de Triomphe
# 97         232  131865                Charming 30 m studio up to 2 people
# 98         233  132533  ****CHEAP****Private****LIFT****Eiffel TOwer**...
# 99         235  136687                Nice studio Latin district/Sorbonne
#
#                                               summary  \
# ...

# %%
df6.id.unique()
# Out:
# array([  5396,   7964,   9359,  10010,  10270,  11213,  11265,  11798,
#         14011,  14757,  16455,  16457,  17918,  17919,  19306,  20823,
#         21167,  21194,  21264,  21860,  22384,  23502,  26278,  26567,
#         28829,  29713,  31435,  31893,  33114,  33210,  33814,  33993,
#         34059,  34453,  35065,  36221,  36868,  39666,  41213,  43355,
#         44123,  44130,  45630,  47155,  48498,  48584,  48592,  50677,
#         53036,  53353,  54377,  54958,  56662,  57207,  57766,  59182,
#         59508,  59959,  60868,  61016,  61453,  62622,  64472,  69083,
#         70586,  71495,  72427,  72895,  75709,  77482,  78366,  80301,
#         81106,  84820,  84988,  85145,  86053,  89058,  89121,  91139,
#         93287,  93408,  94270, 106220, 107038, 108201, 110322, 113114,
#        114543, 118731, 121893, 122179, 124104, 124251, 128423, 130420,
#        131487, 131865, 132533, 136687])
